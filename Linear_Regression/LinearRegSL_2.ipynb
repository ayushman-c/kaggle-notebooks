# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushman-c/kaggle-notebooks/blob/main/Linear_Regression/LinearRegSL_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/data.csv")

# %%
df.head(3)
print(df.shape)
# Out:
# (4600, 18)

# %%
Y = df['price']
df['total_sqft'] = df['sqft_above']+df['sqft_living']+df['sqft_lot']+df['sqft_basement']
X = df['total_sqft']

# %%
print(X.head(3))
print(Y.head(3))
# Out:
# 0    10592
# 1    16350
# 2    15807
# Name: total_sqft, dtype: int64
# 0     313000.0
# 1    2384000.0
# 2     342000.0
# Name: price, dtype: float64

# %%
sns.scatterplot(data=df,x='price',y='total_sqft')
# Out:
# <Axes: xlabel='price', ylabel='total_sqft'>

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=2)
print(X_train.head(3))
print(y_train.head(3))
X_train = X_train.values.reshape(-1,1)
y_train = y_train.values.reshape(-1,1)
# Out:
# 2274    11860
# 2735    12703
# 4       14380
# Name: total_sqft, dtype: int64
# 2274    522000.0
# 2735    284950.0
# 4       550000.0
# Name: price, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
sns.scatterplot(data=df,x='price',y='total_sqft')
plt.plot(X_train,lr.predict(X_train),color="red")

# %%
lr.predict(X_test.iloc[[0]].values.reshape(-1, 1))
# Out:
# array([[546667.2049765]])

# %%
print(X_test.head(3))
print(y_test.head(3))
# Out:
# 4111    17920
# 1996    34419
# 2307    10680
# Name: total_sqft, dtype: int64
# 4111     232000.0
# 1996     299950.0
# 2307    1085000.0
# Name: price, dtype: float64
